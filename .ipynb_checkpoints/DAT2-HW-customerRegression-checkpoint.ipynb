# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math

# %%
customer = pd.read_csv("data/customerRegressionFull.csv")

# %%
customer.head()
# Out:
#    age  Computer  TV  Cellphone  Software  Frequency3     Monetary3  \
# 0   37         4   1          0         2           7  1.607621e+06
# 1   21         4   1          1         1           7  1.654844e+06
# 2   20         1   2          2         1           6  1.884846e+06
# 3   11         0   3          0         2           5  1.415478e+06
# 4   17         0   2          1         0           3  1.669848e+06
#
#      Monetary60
# 0  3.220018e+06
# 1  4.792484e+06
# 2  4.681646e+06
# 3  5.861252e+06
# 4  3.914121e+06

# %%
customer.describe()
# Out:
#                 age      Computer            TV     Cellphone      Software  \
# count  13000.000000  13000.000000  13000.000000  13000.000000  13000.000000
# mean      25.046462      3.016154      1.491538      0.997692      3.504231
# std        8.995840      1.994465      1.118870      0.818564      2.288248
# min       10.000000      0.000000      0.000000      0.000000      0.000000
# 25%       17.000000      1.000000      0.000000      0.000000      2.000000
# 50%       25.000000      3.000000      1.000000      1.000000      3.000000
# 75%       33.000000      5.000000      2.000000      2.000000      6.000000
# max       40.000000      6.000000      3.000000      2.000000      7.000000
#
#          Frequency3     Monetary3    Monetary60
# count  13000.000000  1.300000e+04  1.300000e+04
# mean       9.009615  1.902235e+06  5.702409e+06
# std        3.329020  4.604723e+05  2.028901e+06
# min        0.000000  5.632493e+05  4.924054e+04
# 25%        7.000000  1.575859e+06  4.304843e+06
# 50%        9.000000  1.869747e+06  5.616521e+06
# 75%       11.000000  2.190582e+06  7.001595e+06
# max       18.000000  3.867106e+06  1.459052e+07

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(customer, figsize = (6, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a063d62e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a043a6588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0435b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0430ea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a042c2cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a04277f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a042351d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0426b400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0426b470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a041d1908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a04182b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a04136dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a063ee5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a041f6860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a040d4390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a040865f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0403b860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0406cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a04020d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03fd4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03f94240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03f484a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03efa710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03f2f978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03ee0be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03e97e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03e570f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03e0a358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03dbb5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03dee828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03da3a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03d54cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03d0bf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03ccb208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03c7e470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03cb16d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03c63940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03c18ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03bcce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03b8b0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03b3f320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03b72588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03b2a2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03ad9630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03a8b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03a3fd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a039fc0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03a2d470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a039df7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03990b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03942ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a039032b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a038b3630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a038e39b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03896d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a038540f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03806470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a037b67f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a037e9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a0379cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a037582b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a03708630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a036bc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5a036ebd30>]],
#       dtype=object)

# %%
import seaborn as sns 

plt.figure(figsize=(6,6))
cor = customer.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(inputs):

    vif = pd.DataFrame()
    vif["variables"] = inputs.columns
    vif["VIF"] = [variance_inflation_factor(inputs.values, i) for i in range(inputs.shape[1])]

    return(vif)

# %%
customer2 = customer.drop(['Monetary60'], axis=1)

calc_vif(customer2)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     variables        VIF
# 0         age   6.273384
# 1    Computer        inf
# 2          TV        inf
# 3   Cellphone        inf
# 4    Software        inf
# 5  Frequency3        inf
# 6   Monetary3  24.175428

# %%
import statsmodels.api as sm 

x = customer.drop(['Monetary60'],axis=1)
y = customer['Monetary60']

x_train, x_test, y_train, y_test = train_test_split(x, y)

X_train = sm.add_constant(x_train)

model = sm.OLS(y_train,X_train).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Monetary60   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     509.4
# Date:                Wed, 16 Sep 2020   Prob (F-statistic):               0.00
# Time:                        05:23:01   Log-Likelihood:            -1.5406e+05
# No. Observations:                9750   AIC:                         3.081e+05
# Df Residuals:                    9743   BIC:                         3.082e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.098e+06   9.15e+04     33.876      0.000    2.92e+06    3.28e+06
# age          383.6951   1983.552      0.193      0.847   -3504.478    4271.868
# Computer     7.21e+04   9147.252      7.882      0.000    5.42e+04       9e+04
# TV          3.257e+04   1.37e+04      2.371      0.018    5648.337    5.95e+04
# Cellphone   6.658e+04   1.81e+04      3.683      0.000    3.11e+04    1.02e+05
# Software     6.65e+04   8574.805      7.755      0.000    4.97e+04    8.33e+04
# Frequency3  2.377e+05   7465.264     31.846      0.000    2.23e+05    2.52e+05
# Monetary3     -0.0656      0.057     -1.156      0.248      -0.177       0.046
# ==============================================================================
# Omnibus:                        5.363   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.663
# Skew:                          -0.024   Prob(JB):                       0.0589
# Kurtosis:                       3.108   Cond. No.                     9.42e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.21e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_train = X_train.drop(['age'], axis=1)

model = sm.OLS(y_train,X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Monetary60   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     611.4
# Date:                Wed, 16 Sep 2020   Prob (F-statistic):               0.00
# Time:                        05:23:01   Log-Likelihood:            -1.5406e+05
# No. Observations:                9750   AIC:                         3.081e+05
# Df Residuals:                    9744   BIC:                         3.082e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.108e+06   7.77e+04     40.010      0.000    2.96e+06    3.26e+06
# Computer    7.209e+04   9146.761      7.882      0.000    5.42e+04       9e+04
# TV          3.255e+04   1.37e+04      2.370      0.018    5628.900    5.95e+04
# Cellphone   6.662e+04   1.81e+04      3.686      0.000    3.12e+04    1.02e+05
# Software    6.648e+04   8574.140      7.754      0.000    4.97e+04    8.33e+04
# Frequency3  2.377e+05   7464.779     31.849      0.000    2.23e+05    2.52e+05
# Monetary3     -0.0654      0.057     -1.154      0.249      -0.177       0.046
# ==============================================================================
# Omnibus:                        5.344   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                5.643
# Skew:                          -0.024   Prob(JB):                       0.0595
# Kurtosis:                       3.108   Cond. No.                     1.60e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.47e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_train = X_train.drop(['Monetary3'], axis=1)

model = sm.OLS(y_train,X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Monetary60   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     763.9
# Date:                Wed, 16 Sep 2020   Prob (F-statistic):               0.00
# Time:                        05:23:01   Log-Likelihood:            -1.5406e+05
# No. Observations:                9750   AIC:                         3.081e+05
# Df Residuals:                    9745   BIC:                         3.082e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.042e+06   5.33e+04     57.066      0.000    2.94e+06    3.15e+06
# Computer     7.08e+04   9078.400      7.799      0.000     5.3e+04    8.86e+04
# TV          3.149e+04   1.37e+04      2.298      0.022    4631.247    5.83e+04
# Cellphone   6.499e+04    1.8e+04      3.607      0.000    2.97e+04       1e+05
# Software    6.518e+04   8499.465      7.669      0.000    4.85e+04    8.18e+04
# Frequency3  2.325e+05   5895.153     39.433      0.000    2.21e+05    2.44e+05
# ==============================================================================
# Omnibus:                        5.420   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                5.723
# Skew:                          -0.025   Prob(JB):                       0.0572
# Kurtosis:                       3.108   Cond. No.                     2.71e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.62e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_test = x_test.drop(['age', 'Monetary3'],axis=1)
X_test = sm.add_constant(x_test)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

rmse = math.sqrt(mean_squared_error(y_pred, y_test))
rmse
# Out:
# 1785046.287764283

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_pred, y_test)
mae
# Out:
# 1414414.543951542
